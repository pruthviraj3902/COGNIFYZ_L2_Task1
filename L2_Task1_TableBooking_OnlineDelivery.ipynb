# %% [markdown]
# # Task 01: Table Booking & Online Delivery Analysis
#
# ## ➣ Objective
#
# - To analyze restaurant services such as table booking and online delivery, and study their relationship with ratings and price ranges.
#
# ## ➣ Tools Used
#
# - Python
# - Pandas
# - Matplotlib
# - Seaborn
# - Google Colab

# %% [markdown]
# ## Step 1: Import Libraries & Load Dataset
#
# - In this step, we import necessary libraries and load the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Dataset.csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Step 2: Understanding Table Booking & Online Delivery Data
#
# - Here, we explore columns related to table booking and online delivery services.

# %%
df[['Has Table booking', 'Has Online delivery']].head()
# Out:
#   Has Table booking Has Online delivery
# 0               Yes                  No
# 1               Yes                  No
# 2               Yes                  No
# 3                No                  No
# 4               Yes                  No

# %% [markdown]
# ## Step 3: Percentage of Restaurants Offering Table Booking
#
# - This step calculates the percentage of restaurants that offer table booking.

# %%
table_booking_percentage = (
    df['Has Table booking'].value_counts(normalize=True) * 100
)

print(table_booking_percentage)
# Out:
# Has Table booking
# No     87.875615
# Yes    12.124385
# Name: proportion, dtype: float64

# %% [markdown]
# ## Step 4: Percentage of Restaurants Offering Online Delivery
#
# - This step calculates the percentage of restaurants that offer online delivery.

# %%
online_delivery_percentage = (
    df['Has Online delivery'].value_counts(normalize=True) * 100
)

print(online_delivery_percentage)
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: proportion, dtype: float64

# %% [markdown]
# ## Step 5: Average Ratings Based on Table Booking Availability
#
# - This analysis compares average ratings of restaurants with and without table booking.

# %%
avg_rating = df.groupby('Has Table booking')['Aggregate rating'].mean()

print(avg_rating)
# Out:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ## Step 6: Visualization of Average Ratings
#
# - This chart compares average ratings for restaurants with and without table booking.

# %%
sns.barplot(
    x=avg_rating.index,
    y=avg_rating.values
)

plt.title("Average Rating by Table Booking")
plt.ylabel("Average Rating")
plt.show()

# %% [markdown]
# ## Step 7: Online Delivery Across Price Ranges
#
# - This chart analyzes online delivery availability among different price ranges.

# %%
sns.countplot(
    x='Price range',
    hue='Has Online delivery',
    data=df
)

plt.title("Online Delivery Across Price Ranges")
plt.show()

# %% [markdown]
# ## ➣ Conclusion
#
# - Calculated percentage of restaurants offering table booking and online delivery
# - Compared average ratings based on table booking availability
# - Analyzed online delivery services across different price ranges
# - Observed relationships between restaurant services and ratings
#
# This analysis helps understand customer convenience services in restaurants.
